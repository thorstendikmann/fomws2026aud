# %% [markdown]
# # Interactive Bresenham Line Rasterization
#
# Step through Bresenham's algorithm. The plot shows the ideal line, all candidate raster cells, the pixels selected so far, and the current pixel. The state panel explains how the lecture's `error` variable changesand when a decision is taken to 'correct' the y-value.
#
# Requirements: Python 3, `matplotlib`, and `ipywidgets`.
#
# _Hint:_ The source code has been AI-generated for the purpose of visualizing the algorithm.

# %% [markdown]
# Algorithm given in the lecture:
#
# ```text
# fehler = dx / 2
# WHILE x < xend
#    x = x + 1
#    fehler = fehler - dy
#    IF fehler < 0 THEN
#       y = y + 1
#       fehler = fehler + dx
#    END IF
#    SETPIXEL x, y
# END WHILE
# ```

# %%
from bresenham_line_logic import create_visualizer
create_visualizer()
