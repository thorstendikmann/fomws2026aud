# %% [markdown]
# # Interactive Towers of Hanoi
#
# Step through the recursive Towers of Hanoi algorithm. The plot shows the three pegs A, B, C with discs stacked by size; the disc moved in the current step is outlined in red. The state panel shows which disc moves where and at what recursion depth, and the move log lists every step taken so far.
#
# Requirements: Python 3, `matplotlib`, and `ipywidgets`.
#
# _Hint:_ The source code has been AI-generated for the purpose of visualizing the algorithm.

# %% [markdown]
# Algorithm given in the lecture:
#
# ```c
# void hanoi(int n, char A, char B, char C)
# {
#     if (n == 1)
#     {
#         steps++;
#         printf("%5d - Move %c -> %c\n", steps, A, C);
#         return;
#     }
#     hanoi(n - 1, A, C, B);
#     hanoi(1, A, B, C);
#     hanoi(n - 1, B, A, C);
# }
# ```

# %%
from hanoi_towers_logic import create_visualizer
create_visualizer()
